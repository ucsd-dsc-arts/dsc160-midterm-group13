# %%
import cv2
import os
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Based on https://www.pyimagesearch.com/2015/09/07/blur-detection-with-opencv/

# %%
def calculate_blur(img):
    return cv2.Laplacian(img, cv2.CV_64F).var()

# %%
lst = os.listdir('data/scenes/toy_story_4')
dct = {}
for img_name in lst:
    if not os.path.isdir(img_name):
        img = cv2.imread(os.path.join('data/scenes/toy_story_4/', img_name))
        if type(img) != type(None):
            dct[img_name] = calculate_blur(img)
df = pd.Series(dct)

# %%
display(df.argmax(), df.values.max())
# Out:
# C:\Users\xinrui zhan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   """Entry point for launching an IPython kernel.
# 'toy_story_4-Scene-14-1.jpg'
# 349.5976377969349

# %%
display(df.argmin(), df.values.min())
# Out:
# C:\Users\xinrui zhan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
#   """Entry point for launching an IPython kernel.
# 'toy_story_4-Scene-9-1.jpg'
# 8.456849689619538

# %%
plt.imshow(cv2.imread('data/toy_store_4_/resize5/619.jpg')[:,:,::-1])

# %%
plt.imshow(cv2.imread('data/toy_store_4_/resize5/113.jpg')[:,:,::-1])
